# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Importing the csv Dataset as pandas dataframe

data = pd.read_csv('dataset/Student_data.csv')

# %%
# Showing the Top 5 records

data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Checking the shape of the dataset

data.shape
# Out:
# (1000, 8)

# %%
# Dataset checks
# Checking missing values
# Checking Duplicates
# Checking datatypes
# Checking the unique values
# Checking the Statitices
# Checking the various categorical column present in the categorical column

# Checking null values
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Obeservation : There are no observation

# %%
# Checking the duplicated values

data.duplicated().sum()
# Out:
# 0

# %%
# Observation : There are no duplicated values

# %%
# Checking the datatypes

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Checking the no of unique values

data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
# Checking the Statistices 

data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
for col in data:
    if data[col].dtype =='object':
        print(f'unique category variables {col} in data are : ',data[col].unique())
#     print(data[col].dtype)
# Out:
# unique category variables gender in data are :  ['female' 'male']
# unique category variables race/ethnicity in data are :  ['group B' 'group C' 'group A' 'group D' 'group E']
# unique category variables parental level of education in data are :  ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# unique category variables lunch in data are :  ['standard' 'free/reduced']
# unique category variables test preparation course in data are :  ['none' 'completed']

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['Total_score'] =  data['math score'] + data['reading score'] + data['writing score']
data['Average'] = data['Total_score']/3
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
for col in data:
    if data[col].dtype !='object':
        print(f'The no of students got full marks in {col} :',data[data[col]==100].count())
# Out:
# The no of students got full marks in math score : gender                         7
# race/ethnicity                 7
# parental level of education    7
# lunch                          7
# test preparation course        7
# math score                     7
# reading score                  7
# writing score                  7
# Total_score                    7
# Average                        7
# dtype: int64
# The no of students got full marks in reading score : gender                         17
# race/ethnicity                 17
# parental level of education    17
# lunch                          17
# test preparation course        17
# math score                     17
# reading score                  17
# writing score                  17
# Total_score                    17
# Average                        17
# dtype: int64
# The no of students got full marks in writing score : gender                         14
# race/ethnicity                 14
# ...

# %%
data.describe()
# Out:
#        math score  reading score  writing score  Total_score      Average
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    67.770667
# std      15.16308      14.600192      15.195657    42.771978    14.257326
# min       0.00000      17.000000      10.000000    27.000000     9.000000
# 25%      57.00000      59.000000      57.750000   175.000000    58.333333
# 50%      66.00000      70.000000      69.000000   205.000000    68.333333
# 75%      77.00000      79.000000      79.000000   233.000000    77.666667
# max     100.00000     100.000000     100.000000   300.000000   100.000000

# %%
for col in data:
    if data[col].dtype !='object':
        print(f'The no of students got full marks in {col} :',data[data[col]==100]['Average'].count())
# Out:
# The no of students got full marks in math score : 7
# The no of students got full marks in reading score : 17
# The no of students got full marks in writing score : 14
# The no of students got full marks in Total_score : 0
# The no of students got full marks in Average : 3

# %%
for col in data:
    if data[col].dtype !='object':
        print(f'The no of students got full marks in {col} :',data[data[col]<=25]['Average'].count())
# Out:
# The no of students got full marks in math score : 7
# The no of students got full marks in reading score : 4
# The no of students got full marks in writing score : 5
# The no of students got full marks in Total_score : 0
# The no of students got full marks in Average : 4

# %%
# Oberservation :
# Students are have poor performance in maths
# Studnet are have better performance in reading score

# %%
colors = 'blue green red yellow black'.split(' ')
i = 0
for col in data.drop(columns='Total_score,Average'.split(',')):
    if data[col].dtype !='object':
        sns.kdeplot(data=data,x=data[col],shade=True,color=colors[i],label=col)
        plt.xlabel('scores')
        plt.legend(loc='upper left')
        i+=1

# %%
plt.figure(figsize=(20,7))
plt.subplot(141)
sns.histplot(data,x='Average',kde=True,bins=30)
plt.subplot(142)
sns.histplot(data,x='Average',kde=True,bins=30,hue='race/ethnicity')
plt.subplot(143)
sns.histplot(data,x='Average',kde=True,bins=30,hue='gender')
# Out:
# <AxesSubplot:xlabel='Average', ylabel='Count'>

# %%
female_data = data[data['gender']=='female']
male_data = data[data['gender']=='male']
sns.kdeplot(data=female_data,x='Average',shade=True,label='Female')
sns.kdeplot(data=male_data,x='Average',shade=True,label='male')
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(20,7))
plt.subplot(141)
sns.histplot(data,x='Average',kde=True,bins=30)
plt.subplot(142)
sns.histplot(female_data,x='Average',kde=True,bins=30,hue='lunch')
plt.subplot(143)
sns.histplot(male_data,x='Average',kde=True,bins=30,hue='gender')
# Out:
# <AxesSubplot:xlabel='Average', ylabel='Count'>

# %%
# Obeservation :
# Femate has gained more than the male 
# Standard lunch helps in get more Average of marks
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.figure(figsize=(20,7))
plt.subplot(141)
sns.histplot(data,x='Average',kde=True,bins=30)
plt.subplot(142)
sns.histplot(female_data,x='Average',kde=True,bins=30,hue='parental level of education')
plt.subplot(143)
sns.histplot(male_data,x='Average',kde=True,bins=30,hue='gender')
# Out:
# <AxesSubplot:xlabel='Average', ylabel='Count'>

# %%
for val in data['parental level of education'].unique():
    df = data[data['parental level of education']==f"{val}"]
    sns.kdeplot(data=df,x=df['Average'],shade=True,label=val)
plt.legend(loc='upper left')

# %%
plt.hist(data['Average'])
# Out:
# (array([  1.,   5.,  12.,  40., 124., 178., 262., 210., 122.,  46.]),
#  array([  9. ,  18.1,  27.2,  36.3,  45.4,  54.5,  63.6,  72.7,  81.8,
#          90.9, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
# parent_corr =  data.groupby('parental level of education,gender'.split(',')).sum().reset_index()
# plt.figure(figsize=(15,8))
# for col in parent_corr:
#     if parent_corr[col].dtype != 'object':
plt.figure(figsize=(15,6))
sns.barplot(data=data,x='parental level of education',y=col,hue='gender',palette='prism')
plt.legend()

plt.figure(figsize=(15,6))
sns.barplot(data=female_data[female_data['Average']>=50],x='parental level of education',y=col,hue='gender',palette='inferno')
plt.legend()

plt.figure(figsize=(15,6))
sns.barplot(data=male_data[male_data['Average']>=70],x='parental level of education',y=col,hue='gender',palette='icefire')
plt.legend()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='Average',kde=True,hue='parental level of education')
plt.subplot(142)
ax =sns.histplot(data=female_data,x='Average',kde=True,hue='parental level of education')
plt.subplot(143)
ax =sns.histplot(data=male_data,x='Average',kde=True,hue='parental level of education')
plt.show()

# %%
plt.figure(figsize=(22,7))
plt.subplot(121)
unqiues = [val for val in male_data['parental level of education'].unique()]
data_values = [i for i in male_data[male_data['Average']>=75]['parental level of education']]
x = [data_values.count(val) for val in unqiues]
plt.barh(unqiues,x,color='red')
plt.xlabel('Male Disturbution')

plt.subplot(122)
data_values = [i for i in female_data[female_data['Average']>=75]['parental level of education']]
x = [data_values.count(val) for val in unqiues]
plt.barh(unqiues,x,color='lightgreen')
plt.xlabel('Female Disturbution')
# Out:
# Text(0.5, 0, 'Female Disturbution')

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.subplot(141)
for i in data['race/ethnicity'].unique():
    sns.kdeplot(data=data[data['race/ethnicity']==i],x='Average',shade=True,label=i)
plt.legend(loc='upper left')
plt.subplot(142)
for i in data['race/ethnicity'].unique():
    sns.kdeplot(data=female_data[female_data['race/ethnicity']==i],x='Average',shade=True,label=i)
plt.legend(loc='upper left')
plt.subplot(143)
for i in data['race/ethnicity'].unique():
    sns.kdeplot(data=male_data[male_data['race/ethnicity']==i],x='Average',shade=True,label=i)
plt.legend(loc='upper left')

# %% [markdown]
# ##### insights
# - group A , B children are performing poor in the exams
# - even for the both of the gender

# %%
plt.figure(figsize=(15,8))
plt.subplot(141)
plt.title('Maths')
sns.violinplot(data=data['math score'],color='red',linewidth=2)
plt.subplot(142)
plt.title('readings')
sns.violinplot(data=data['reading score'],color='green')
plt.subplot(143)
plt.title('writing ')
sns.violinplot(data=data['writing score'],color='yellow')
# Out:
# <AxesSubplot:title={'center':'writing '}>

# %%
plt.subplot(121)
sns.violinplot(data=data['Average'],color='red')
plt.subplot(122)
sns.violinplot(data=male_data['Average'].reset_index(drop=True),color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Insight
# - We can see the math score is b/w 60 - 80 and writing score and reading score is b/w 50 - 80

# %%
# Multivariate analysis
# plt.rcParams['figure.figsize'] = (50, 12)
plt.figure(figsize=(35,12))
for i,col in enumerate(data) :
    if data[col].dtype=='object' :
        labels = data[col].value_counts().index
        size = data[col].value_counts()
        plt.subplot(1,5,i+1)
        plt.pie(size,labels=labels,autopct='.%2f%%')
        plt.title(col)

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# ##### Insights -
# - Almost equal in gender
# - Group B and C students are more
# - Bachelor's Degree and some college parents children are more in the school
# - Standard lunch is more
# - Student with no course are more

# %%
ax = sns.countplot(data['gender'],palette='copper')
for i in ax.containers : ax.bar_label(i, label_type='edge')

# %%
# Bivarate analysis 
gender_group = data.groupby('gender',as_index=True).mean().reset_index()
gender_group
# Out:
#    gender  math score  reading score  writing score  Total_score    Average
# 0  female   63.633205      72.608108      72.467181   208.708494  69.569498
# 1    male   68.728216      65.473029      63.311203   197.512448  65.837483

# %%
plt.figure(figsize=(19,7))
plt.subplot(1,4,1)
ax = sns.barplot(y='math score',x='gender',data=gender_group,palette='spring')
plt.title('math score')
for label in ax.containers : 
    ax.bar_label(label)


plt.subplot(1,4,2)
ax = sns.barplot(y='reading score',x='gender',data=gender_group,palette='rocket')
plt.title('reading score')
for label in ax.containers : 
    ax.bar_label(label)
    
    

plt.subplot(1,4,3)
ax = sns.barplot(y='writing score',x='gender',data=gender_group,palette='summer')
plt.title('writing score')
for label in ax.containers : 
    ax.bar_label(label)


plt.subplot(1,4,4)
ax = sns.barplot(y='Average',x='gender',data=gender_group,palette='bone')
plt.title('Average')
for label in ax.containers : 
    ax.bar_label(label)

# %% [markdown]
# ##### insight
# - Female has high Average
# - Male has high score than Female in maths

# %%
# univarate analysis
plt.figure(figsize=(15,7))
plt.subplot(121)
ax = sns.countplot(data['race/ethnicity'],saturation=1,palette='rainbow')
plt.title('race/ethnicity disturbution on bar chart')
for i in ax.containers : ax.bar_label(i)

plt.subplot(122)
plt.pie(data['race/ethnicity'].value_counts(),labels=data['race/ethnicity'].value_counts().index,explode=[0.1,0,0,0,0],shadow=True,autopct='.%1.1f%%')
plt.title('race/ethnicity disturbution on pie')
# Out:
# Text(0.5, 1.0, 'race/ethnicity disturbution on pie')

# %%
# Bivarate analysis
race_group = data.groupby('race/ethnicity').mean().reset_index()
columns =  'math score,reading score,writing score'.split(',')
plt.figure(figsize=(25,7))
for i,col in enumerate(columns):
    plt.subplot(1,4,i+1)
    ax=sns.barplot(race_group['race/ethnicity'],race_group[col],saturation=1,palette='mako')
    for label in ax.containers : ax.bar_label(label,color='black')
    plt.title(col+' Distuburtion',color='#005ce6',fontsize=20,pad=20)

# %% [markdown]
# ##### insight :
# - Group A students have poor Average
# - Group E students have high Average

# %%
plt.figure(figsize=(15,7))
ax=sns.countplot(data['parental level of education'],palette='flare')
for label in ax.containers: ax.bar_label(label)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total_score    Average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(15,10))
ax = sns.barplot(data=data,x='gender',y='math score',hue='parental level of education',palette='turbo')
for i in ax.containers : ax.bar_label(i)
plt.legend(loc='upper left')

# %%
parent_data =  data.groupby(['parental level of education']).mean().reset_index()
plt.figure(figsize=(35,12))
for i,col in enumerate(columns):
    plt.subplot(1,3,i+1)
    ax=sns.barplot(parent_data['parental level of education'],parent_data[col],palette='icefire')
    plt.title(col,pad=30,fontsize=30,fontweight=20)
    for i in ax.containers: ax.bar_label(i)

# %%
plt.figure(figsize=(20,12))
parent_data.plot(kind='barh',x='parental level of education',figsize=(12,10))
# Out:
# <AxesSubplot:ylabel='parental level of education'>

# %%
sns.countplot(data['lunch'],palette='hot')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
lunch_data =  data.groupby(['lunch']).mean().reset_index()
plt.figure(figsize=(15,5))
for i,col in enumerate(columns):
    plt.subplot(1,3,i+1)
    ax=sns.barplot(lunch_data['lunch'],lunch_data[col],palette='cool')
    plt.title(col,pad=10,fontsize=15,fontweight=20)
    for i in ax.containers: ax.bar_label(i)

# %%
plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
ax=sns.countplot(data['parental level of education'],hue=data['lunch'],palette='turbo')
plt.title('parental level of education vs lunch',fontsize=20,pad=20)
for i in ax.containers: ax.bar_label(i)
plt.subplot(1,2,2)
ax = sns.countplot(data['parental level of education'],hue=data['test preparation course'],palette='turbo')
for i in ax.containers: ax.bar_label(i)
plt.title('parental level of education vs test preperation course',fontsize=20,pad=20)
# Out:
# Text(0.5, 1.0, 'parental level of education vs test preperation course')

# %%
plt.figure(figsize=(25,9))
for i,col in enumerate(columns):
    plt.subplot(1,4,i+1)
    ax=sns.barplot(y=data[col],x=data['test preparation course'],hue=data['lunch'],palette='prism')
    for i in ax.containers: ax.bar_label(i)
    plt.title(col)

# %%
sns.pairplot(data,hue='gender')

# %% [markdown]
# ### 5. Conclusions
# - We can see that all are high positively correlated to each other
# - Student's Performance is related with lunch, race, parental level education
# - Females lead in pass percentage and also are top-scorers
# - Student's Performance is not much related with test preparation course
# - Finishing preparation course is benefitial.

# %%
data.to_csv('dataset/stud.csv')
